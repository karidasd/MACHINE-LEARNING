# %% [markdown]
# # 📈 Μάθημα 2: Ανάλυση Πραγματικών Δεδομένων
# Σήμερα θα μάθουμε πώς να φορτώνουμε ένα αρχείο CSV και να απαντάμε σε ερωτήσεις.

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Φόρτωση των δεδομένων
try:
    df = pd.read_csv('../02_Datasets/sales_data.csv')
    df['Συνολικό_Έσοδο'] = df['Τιμή'] * df['Ποσότητα']
    print("✅ Τα δεδομένα φορτώθηκαν επιτυχώς!")
    display(df.head())
except:
    print("❌ Σφάλμα: Βεβαιωθείτε ότι το αρχείο sales_data.csv υπάρχει στον σωστό φάκελο.")

# %% [markdown]
# ---
# ## 🏆 Data Challenge: Ο Αναλυτής του Μήνα
# Τώρα είναι η σειρά σας! Συμπληρώστε τον κώδικα στα παρακάτω κελιά:
#
# 1. **Ποιο προϊόν πουλήθηκε τις περισσότερες φορές;** (Χρησιμοποιήστε τη στήλη `Ποσότητα`)
# 2. **Ποια ήταν η πιο ακριβή αγορά που έγινε;** (Η μέγιστη τιμή στη στήλη `Συνολικό_Έσοδο`)
# 3. **Bonus:** Φτιάξτε ένα Bar Chart που να δείχνει τα έσοδα ανά **Προϊόν**.

# %%
# Γράψτε τη λύση για το ερώτημα 1 εδώ:

# %%
# Γράψτε τη λύση για το ερώτημα 2 εδώ:
